# %%
import os
import random
from dotenv import load_dotenv
import finnhub
import math
from datetime import datetime, timedelta
from pandas_datareader import data
from bokeh.plotting import figure, show, output_file
from bokeh.io import export_png
from bokeh.models import ColumnDataSource, Grid, LinearAxis, Plot, Text
from selenium.webdriver import Chrome, ChromeOptions

p = figure(x_axis_type='datetime',plot_width=1000,plot_height=300)
p.grid.grid_line_alpha=0.3

configuration = finnhub.Configuration(
    api_key={
        'token': 'bs1oipfrh5rbe4rks0i0' # Replace this
    }
)

finnhub_client = finnhub.DefaultApi(finnhub.ApiClient(configuration))

data = finnhub_client.recommendation_trends('T')


data2 = data[0:6]

for item in data2:
    print(item)
    total = int(item.buy) + int(item.hold) + int(item.sell) + int(item.strong_buy) + int(item.strong_sell)
    col1 = datetime.strptime(item.period,"%Y-%m-%d") 
    p.segment(x0= col1, x1=col1,y0=total-int(item.strong_buy),y1=total,line_color="#0f8058",line_width= 40)
    glyph1 = Text(x=col1, y=total-(item.strong_buy/2), text=[str(item.strong_buy)], text_color="#000000",text_align="center")
    p.add_glyph(glyph1) if item.strong_buy > 0 else print("swag")
    total = total-int(item.strong_buy)
    p.segment(x0= col1, x1=col1,y0=total-int(item.buy),y1=total,line_color="#02c983",line_width= 40)
    glyph2 = Text(x=col1, y=total-(item.buy/2), text=[str(item.buy)], text_color="#000000",text_align="center")
    p.add_glyph(glyph2) if item.buy > 0 else print("swag")
    total = total-int(item.buy)
    p.segment(x0= col1, x1=col1,y0=total-int(item.hold),y1=total,line_color="#cf8a0a",line_width= 40)
    glyph3 = Text(x=col1, y=total-(item.hold/2), text=[str(item.hold)], text_color="#000000",text_align="center")
    p.add_glyph(glyph3) if item.hold > 0 else print("swag")
    total = total-int(item.hold)
    p.segment(x0= col1, x1=col1,y0=total-int(item.sell),y1=total,line_color="#ffda08",line_width= 40)
    glyph4 = Text(x=col1, y=total-(item.sell/2), text=[str(item.sell)], text_color="#000000",text_align="center")
    p.add_glyph(glyph4) if item.sell > 0 else print("swag")
    total = total-int(item.sell)
    p.segment(x0= col1, x1=col1,y0=total-int(item.strong_sell),y1=total,line_color="#b02b13",line_width= 40)
    glyph5 = Text(x=col1, y=total-(item.strong_sell/2), text=[str(item.strong_sell)], text_color="#000000",text_align="center")
    p.add_glyph(glyph5) if item.strong_sell > 0 else print("swag")
    
output_file("RT.html")
show(p)
# Out:
# {'buy': 6,
#  'hold': 21,
#  'period': '2020-07-01',
#  'sell': 0,
#  'strong_buy': 8,
#  'strong_sell': 1,
#  'symbol': 'T'}
# swag
# {'buy': 8,
#  'hold': 20,
#  'period': '2020-06-01',
#  'sell': 2,
#  'strong_buy': 7,
#  'strong_sell': 1,
#  'symbol': 'T'}
# {'buy': 8,
#  'hold': 20,
#  'period': '2020-05-01',
#  'sell': 2,
#  'strong_buy': 7,
#  'strong_sell': 1,
#  'symbol': 'T'}
# {'buy': 7,
#  'hold': 20,
#  'period': '2020-04-01',
#  'sell': 0,
#  'strong_buy': 7,
#  'strong_sell': 1,
#  'symbol': 'T'}
# swag
# {'buy': 7,
#  'hold': 20,
#  'period': '2020-03-01',
#  'sell': 0,
#  'strong_buy': 7,
#  'strong_sell': 1,
#  'symbol': 'T'}
# swag
# {'buy': 7,
#  'hold': 20,
#  'period': '2020-02-01',
#  'sell': 0,
#  'strong_buy': 7,
#  'strong_sell': 1,
#  'symbol': 'T'}
# swag
